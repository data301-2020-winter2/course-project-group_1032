# %%
# og data set - processed (thank u cole)

import pandas as pd
import numpy as np
import project_functions as pf


df = pf.load_and_process("../../Dataset.csv")
df
# Out:
#        Year           State            Division                        County  \
# 45880  2013        Virginia      South Atlantic             NEWPORT NEWS CITY
# 38924  2013       Tennessee  East South Central  SULLIVAN; CARTER; WASHINGTON
# 38736  2013         Florida      South Atlantic                    MIAMI-DADE
# 38214  2013       Tennessee  East South Central                        SHELBY
# 38213  2013       Tennessee  East South Central                        SHELBY
# ...     ...             ...                 ...                           ...
# 65096  2019      New Mexico            Mountain                    BERNALILLO
# 65095  2019      New Mexico            Mountain                    BERNALILLO
# 65094  2019  North Carolina      South Atlantic                       IREDELL
# 28068  2019  North Carolina      South Atlantic                      GUILFORD
# 5644   2019           Texas  West South Central       PARKER; DENTON; TARRANT
#
#       Region            Population_Description                   Offense  \
# 45880  South  Cities from 100,000 thru 249,999         All Other Larceny
# 38924  South    Cities from 50,000 thru 99,999  Theft From Motor Vehicle
# 38736  South    Cities from 25,000 thru 49,999  Theft From Motor Vehicle
# 38214  South  Cities from 500,000 thru 999,999  Theft From Motor Vehicle
# 38213  South  Cities from 500,000 thru 999,999  Theft From Motor Vehicle
# ...      ...                               ...                       ...
# 65096   West  Cities from 500,000 thru 999,999         All Other Larceny
# 65095   West  Cities from 500,000 thru 999,999         All Other Larceny
# 65094  South      MSA counties 100,000 or over         All Other Larceny
# 28068  South  Cities from 250,000 thru 499,999       Motor Vehicle Theft
# 5644   South  Cities from 500,000 thru 999,999         All Other Larceny
#
#                    Offender_Race      Offender_Ethnicity  Offender_Age  \
# 45880                        NaN                     NaN           NaN
# 38924                        NaN                     NaN           NaN
# 38736                        NaN                     NaN           NaN
# 38214                        NaN                     NaN           NaN
# 38213                        NaN                     NaN           NaN
# ...                          ...                     ...           ...
# 65096                      White      Hispanic or Latino          30.0
# 65095                      White      Hispanic or Latino           NaN
# 65094                      White  Not Hispanic or Latino          45.0
# 28068                      White                 Unknown          24.0
# 5644   Black or African American                 Unknown           NaN
#
#       Offender_Sex Victim_Type                    Location Weapon  \
# 45880          NaN  Individual     Parking/Drop Lot/Garage    NaN
# 38924          NaN    Business     Parking/Drop Lot/Garage    NaN
# 38736          NaN    Business  Commercial/Office Building    NaN
# 38214          NaN    Business  Commercial/Office Building    NaN
# 38213          NaN    Business               Other/Unknown    NaN
# ...            ...         ...                         ...    ...
# 65096            M    Business    Auto Dealership New/Used    NaN
# 65095            M    Business    Auto Dealership New/Used    NaN
# 65094            M    Business  Commercial/Office Building    NaN
# 28068            M  Individual              Residence/Home    NaN
# 5644             M    Business  Commercial/Office Building    NaN
#
#                         Property_Type  Stolen_Value  Recovered_Value  \
# 45880                Consumable Goods        3000.0              0.0
# 38924                           Money        2000.0              0.0
# 38736                  Radio/ TV/ VCR        6576.0              0.0
# 38214                  Radio/ TV/ VCR        1200.0              0.0
# 38213                  Radio/ TV/ VCR        4000.0              0.0
# ...                               ...           ...              ...
# 65096  Recreational/ Sports Equipment       33000.0          33000.0
# 65095  Recreational/ Sports Equipment       33000.0          33000.0
# 65094                           Other        1024.0              0.0
# 28068                      Automobile       15000.0          10000.0
# 5644                  Household Goods       12011.0              0.0
#
#       Recovered? Recovery_Date
# 45880          N           NaN
# 38924          N           NaN
# 38736          N           NaN
# 38214          N           NaN
# 38213          N           NaN
# ...          ...           ...
# 65096          Y     27-Apr-19
# 65095          Y     27-Apr-19
# 65094          N           NaN
# 28068          Y     24-May-19
# 5644           N           NaN
#
# [21111 rows x 19 columns]

# %%
#What areas are most prone to theft

# %%
#What kinds of goods are most commonly stolen?

# %%
#What is the average difference in value between value of goods stolen and recovered or what is the percentage of value recovered?

# %%
#What years were particularly bad for crime?

# %%
#Is there a relationship between population size and crime rate?
